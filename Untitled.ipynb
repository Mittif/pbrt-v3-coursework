# %%
import math

# %%
# def generate_circle_points(r, n):
#     x = []
#     y = []
#     for i in range(n):
#         angle = i * 2 * math.pi / n
#         x.append(round(r * math.cos(angle),2))
#         y.append(round(r * math.sin(angle),2))
        
#         outstring = "LookAt " + str(round(r * math.cos(angle),2)) + " " + str(round(r * math.sin(angle),2)) + " 2.0"
#         + text
#         print (outstring)
#     return x, y

# generate_circle_points(10, 4)

# %%
import math
import os

def generate_pbrt_file(input_file, output_dir, rotation_angle, num_files):
    with open(input_file, 'r') as file:
        content = file.readlines()

    for i in range(num_files):
        angle_rad = math.radians(i * rotation_angle)
        x = -10 * math.sin(angle_rad)
        z = -10 * math.cos(angle_rad)

        new_content = []
        for line in content:
            if line.startswith("LookAt"):
                new_content.append(f"LookAt {x} {z} 2 # eye\n")
            elif "matte_dsphere" in line:
                new_content.append(f'Film "image" "string filename" "matte_dsphere{i+1}.png" ')
            else:
                new_content.append(line)

        output_file = os.path.join(output_dir, f"rotated_{i}.pbrt")
        with open(output_file, 'w') as file:
            file.writelines(new_content)

input_file = "/Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/test.pbrt"
output_dir = "/Users/mitty/Documents/GitHub/pbrt-v3-coursework/test"

num_files = 240
rotation_angle = 360 / num_files

generate_pbrt_file(input_file, output_dir, rotation_angle, num_files)

# %%
import os
import subprocess

def batch_render_pbrt_files(input_dir):
    pbrt_files = [f for f in os.listdir(input_dir) if f.endswith('.pbrt')]

    for pbrt_file in pbrt_files:
        input_file = os.path.join(input_dir, pbrt_file)
        print(f"Rendering {input_file}...")
        result = subprocess.run(["/Users/mitty/Documents/GitHub/pbrt-v3-coursework/cmake-build-debug/pbrt", input_file], capture_output=True, text=True)
        print(result.stdout)
        print(f"Finished rendering {input_file}\n")

input_dir = "/Users/mitty/Documents/GitHub/pbrt-v3-coursework/test"
batch_render_pbrt_files(input_dir)
# Out:
# Rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0128.pbrt...
# pbrt version 3 (built May  7 2023 at 22:12:21) [Detected 10 cores]
# *** DEBUG BUILD ***
# Copyright (c)1998-2018 Matt Pharr, Greg Humphreys, and Wenzel Jakob.
# The source code to pbrt (but *not* the book contents) is covered by the BSD License.
# See the file LICENSE.txt for the conditions of the license.
# vertices: [ -0.0962986201, 0.977738619, 0.0973889679 ]
# vertices: [ -0.126521513, 1.28458929, 0.127517372 ]
#
# Rendering: [                                           ]
# Rendering: [++                                         ]  (0.3s|4.8s)
# Rendering: [+++++                                      ]  (0.5s|4.3s)
# Rendering: [+++++++                                    ]  (0.8s|4.0s)
# Rendering: [+++++++++                                  ]  (1.0s|3.7s)
# Rendering: [+++++++++++                                ]  (1.3s|3.5s)
# Rendering: [++++++++++++++                             ]  (1.5s|3.2s)
# Rendering: [++++++++++++++++                           ]  (1.8s|3.0s)
# Rendering: [+++++++++++++++++                          ]  (2.0s|3.1s)
# Rendering: [++++++++++++++++++                         ]  (2.3s|3.3s)
# Rendering: [++++++++++++++++++                         ]  (2.6s|3.4s)
# Rendering: [+++++++++++++++++++                        ]  (3.1s|3.7s)
# Rendering: [++++++++++++++++++++                       ]  (3.6s|4.0s)
# Rendering: [+++++++++++++++++++++                      ]  (4.1s|4.2s)
# Rendering: [++++++++++++++++++++++                     ]  (4.6s|4.3s)
# Rendering: [+++++++++++++++++++++++                    ]  (5.1s|4.4s)
# Rendering: [++++++++++++++++++++++++                   ]  (5.6s|4.5s)
# Rendering: [+++++++++++++++++++++++++                  ]  (6.1s|4.5s)
# Rendering: [++++++++++++++++++++++++++                 ]  (6.6s|4.5s)
# Rendering: [++++++++++++++++++++++++++                 ]  (7.1s|4.5s)
# Rendering: [+++++++++++++++++++++++++++                ]  (7.6s|4.4s)
# Rendering: [++++++++++++++++++++++++++++               ]  (8.1s|4.2s)
# Rendering: [+++++++++++++++++++++++++++++              ]  (8.6s|4.0s)
# Rendering: [++++++++++++++++++++++++++++++             ]  (9.1s|3.8s)
# Rendering: [+++++++++++++++++++++++++++++++            ]  (9.6s|3.6s)
# Rendering: [++++++++++++++++++++++++++++++++           ]  (10.1s|3.3s)
# Rendering: [+++++++++++++++++++++++++++++++++          ]  (10.6s|3.0s)
# Rendering: [+++++++++++++++++++++++++++++++++++        ]  (11.1s|2.7s)
# Rendering: [++++++++++++++++++++++++++++++++++++       ]  (11.6s|2.4s)
# Rendering: [+++++++++++++++++++++++++++++++++++++      ]  (12.2s|2.0s)
# Rendering: [++++++++++++++++++++++++++++++++++++++     ]  (12.7s|1.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++    ]  (13.2s|1.4s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++   ]  (13.7s|1.1s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++  ]  (14.2s|0.7s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++ ]  (14.7s|0.3s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (15.2s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (15.7s)
# Statistics:
#   BVH
#     Interior nodes                                                   3531
#     Leaf nodes                                                       3532
#     Primitives per leaf node                          3970 /         3532 (1.12x)
#   Integrator
#     Camera rays traced                                           12288000
#     Path length                                                     0.583 avg [range 0 - 1]
#     Zero-radiance paths                             706959 /      7273639 (9.72%)
#   Intersections
#     Regular ray intersection tests                               26152077
#     Shadow ray intersection tests                                 3765358
#     Ray-triangle intersection tests                8703199 /     24076149 (36.15%)
#   Memory
#     BVH tree                                                       282.80 kB
#     Film pixels                                                     12.50 MiB
#     Primitives                                                     279.14 kB
#     Texture MIP maps                                                 0.02 kB
#     TransformCache                                                 260.00 kB
#     Triangle meshes                                                361.87 kB
#   Scene
#     Lights                                                              2
#     Materials created                                                   2
#     Shapes created                                                   3970
#     Probes per TransformCache lookup                                1.000 avg [range 1 - 1]
#     TransformCache hits                                  2 /            6 (33.33%)
#     Triangles per triangle mesh                       3970 /            2 (1985.00x)
#   SpatialLightDistribution
#     Distributions created                                            1205
#     Hash probes per lookup                                          1.014 avg [range 1 - 2]
#     Lookups per distribution                       7273639 /         1205 (6036.21x)
#   Texture
#     Trilinear lookups                                            18238585
#   Profile
#     Integrator::Render()                                            99.70% (   0:00:15.97)
#       Camera::GenerateRay[Differential]()                            9.31% (   0:00:01.49)
#       Film::AddSample()                                              3.01% (   0:00:00.48)
#       Film::MergeTile()                                              0.31% (   0:00:00.05)
#       Sampler::GetSample[12]D()                                      3.72% (   0:00:00.59)
#       Sampler::StartPixelSample()                                    0.02% (   0:00:00.00)
#       SamplerIntegrator::Li()                                       76.81% (   0:00:12.31)
#         Accelerator::Intersect()                                    24.96% (   0:00:04.00)
#           Triangle::Intersect()                                     15.21% (   0:00:02.43)
#         BSDF::Sample_f()                                             3.10% (   0:00:00.49)
#         Direct lighting                                             31.98% (   0:00:05.12)
#           Accelerator::Intersect()                                   5.83% (   0:00:00.93)
#             Triangle::Intersect()                                    1.39% (   0:00:00.22)
#           Accelerator::IntersectP()                                  3.06% (   0:00:00.49)
#             Triangle::IntersectP()                                   0.71% (   0:00:00.11)
#           BSDF::PDF()                                                1.08% (   0:00:00.17)
#           BSDF::Sample_f()                                           2.75% (   0:00:00.44)
#           BSDF::f()                                                  1.64% (   0:00:00.26)
#           Light::Pdf()                                               0.61% (   0:00:00.09)
#           Light::Sample_*()                                          5.13% (   0:00:00.82)
#             MIPMap::Lookup() (trilinear)                             2.28% (   0:00:00.36)
#           MIPMap::Lookup() (trilinear)                               2.23% (   0:00:00.35)
#           Sampler::GetSample[12]D()                                  2.07% (   0:00:00.33)
#         MIPMap::Lookup() (trilinear)                                 1.66% (   0:00:00.26)
#         Material::ComputeScatteringFunctions()                       2.25% (   0:00:00.36)
#         Sampler::GetSample[12]D()                                    0.83% (   0:00:00.13)
#         SpatialLightDistribution lookup                              1.44% (   0:00:00.23)
#           SpatialLightDistribution creation                          0.37% (   0:00:00.05)
#             Light::Sample_*()                                        0.18% (   0:00:00.02)
#               MIPMap::Lookup() (trilinear)                           0.08% (   0:00:00.01)
#     Scene parsing and creation                                       0.30% (   0:00:00.04)
#       Acceleration structure creation                                0.08% (   0:00:00.01)
#   Profile (flattened)
#     Triangle::Intersect()                                           16.59% (   0:00:02.65)
#     Accelerator::Intersect()                                        14.20% (   0:00:02.27)
#     SamplerIntegrator::Li()                                         10.58% (   0:00:01.69)
#     Camera::GenerateRay[Differential]()                              9.31% (   0:00:01.49)
#     Direct lighting                                                  7.56% (   0:00:01.21)
#     Sampler::GetSample[12]D()                                        6.61% (   0:00:01.05)
#     Integrator::Render()                                             6.52% (   0:00:01.04)
#     MIPMap::Lookup() (trilinear)                                     6.25% (   0:00:01.00)
#     BSDF::Sample_f()                                                 5.85% (   0:00:00.93)
#     Film::AddSample()                                                3.01% (   0:00:00.48)
#     Light::Sample_*()                                                2.95% (   0:00:00.47)
#     Accelerator::IntersectP()                                        2.35% (   0:00:00.37)
#     Material::ComputeScatteringFunctions()                           2.25% (   0:00:00.36)
#     BSDF::f()                                                        1.64% (   0:00:00.26)
#     BSDF::PDF()                                                      1.08% (   0:00:00.17)
#     SpatialLightDistribution lookup                                  1.07% (   0:00:00.17)
#     Triangle::IntersectP()                                           0.71% (   0:00:00.11)
#     Light::Pdf()                                                     0.61% (   0:00:00.09)
#     Film::MergeTile()                                                0.31% (   0:00:00.05)
#     Scene parsing and creation                                       0.22% (   0:00:00.03)
#     SpatialLightDistribution creation                                0.20% (   0:00:00.03)
#     Acceleration structure creation                                  0.08% (   0:00:00.01)
#     Sampler::StartPixelSample()                                      0.02% (   0:00:00.00)
#
#
# Finished rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0128.pbrt
#
# Rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0082.pbrt...
# pbrt version 3 (built May  7 2023 at 22:12:21) [Detected 10 cores]
# *** DEBUG BUILD ***
# Copyright (c)1998-2018 Matt Pharr, Greg Humphreys, and Wenzel Jakob.
# The source code to pbrt (but *not* the book contents) is covered by the BSD License.
# See the file LICENSE.txt for the conditions of the license.
# vertices: [ -0.0962986201, 0.977738619, 0.0973889679 ]
# vertices: [ -0.126521513, 1.28458929, 0.127517372 ]
#
# Rendering: [                                           ]
# Rendering: [++                                         ]  (0.3s|5.1s)
# Rendering: [++++                                       ]  (0.5s|4.4s)
# Rendering: [+++++++                                    ]  (0.8s|4.0s)
# Rendering: [+++++++++                                  ]  (1.0s|3.8s)
# Rendering: [+++++++++++                                ]  (1.3s|3.6s)
# Rendering: [++++++++++++++                             ]  (1.5s|3.3s)
# Rendering: [++++++++++++++++                           ]  (1.8s|3.2s)
# Rendering: [+++++++++++++++++                          ]  (2.0s|3.2s)
# Rendering: [++++++++++++++++++                         ]  (2.3s|3.3s)
# Rendering: [++++++++++++++++++                         ]  (2.6s|3.5s)
# Rendering: [+++++++++++++++++++                        ]  (3.1s|3.8s)
# Rendering: [++++++++++++++++++++                       ]  (3.6s|4.1s)
# Rendering: [+++++++++++++++++++++                      ]  (4.1s|4.3s)
# Rendering: [++++++++++++++++++++++                     ]  (4.6s|4.4s)
# Rendering: [+++++++++++++++++++++++                    ]  (5.1s|4.5s)
# Rendering: [++++++++++++++++++++++++                   ]  (5.6s|4.6s)
# Rendering: [+++++++++++++++++++++++++                  ]  (6.1s|4.6s)
# Rendering: [+++++++++++++++++++++++++                  ]  (6.6s|4.6s)
# Rendering: [++++++++++++++++++++++++++                 ]  (7.1s|4.6s)
# Rendering: [+++++++++++++++++++++++++++                ]  (7.6s|4.5s)
# Rendering: [++++++++++++++++++++++++++++               ]  (8.1s|4.3s)
# Rendering: [+++++++++++++++++++++++++++++              ]  (8.6s|4.1s)
# Rendering: [++++++++++++++++++++++++++++++             ]  (9.2s|3.9s)
# Rendering: [+++++++++++++++++++++++++++++++            ]  (9.7s|3.6s)
# Rendering: [++++++++++++++++++++++++++++++++           ]  (10.2s|3.3s)
# Rendering: [+++++++++++++++++++++++++++++++++          ]  (10.7s|3.1s)
# Rendering: [+++++++++++++++++++++++++++++++++++        ]  (11.2s|2.7s)
# Rendering: [++++++++++++++++++++++++++++++++++++       ]  (11.7s|2.4s)
# Rendering: [+++++++++++++++++++++++++++++++++++++      ]  (12.2s|2.1s)
# Rendering: [++++++++++++++++++++++++++++++++++++++     ]  (12.7s|1.8s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++    ]  (13.2s|1.4s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++   ]  (13.7s|1.0s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++  ]  (14.2s|0.6s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++ ]  (14.7s|0.3s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (15.2s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (15.7s)
# Statistics:
#   BVH
#     Interior nodes                                                   3531
#     Leaf nodes                                                       3532
#     Primitives per leaf node                          3970 /         3532 (1.12x)
#   Integrator
#     Camera rays traced                                           12288000
#     Path length                                                     0.578 avg [range 0 - 1]
#     Zero-radiance paths                             612869 /      7254505 (8.45%)
#   Intersections
#     Regular ray intersection tests                               25869605
#     Shadow ray intersection tests                                 3842483
#     Ray-triangle intersection tests                8862083 /     26332028 (33.66%)
#   Memory
#     BVH tree                                                       282.80 kB
#     Film pixels                                                     12.50 MiB
#     Primitives                                                     279.14 kB
#     Texture MIP maps                                                 0.02 kB
#     TransformCache                                                 260.00 kB
#     Triangle meshes                                                361.87 kB
#   Scene
#     Lights                                                              2
#     Materials created                                                   2
#     Shapes created                                                   3970
#     Probes per TransformCache lookup                                1.000 avg [range 1 - 1]
#     TransformCache hits                                  2 /            6 (33.33%)
#     Triangles per triangle mesh                       3970 /            2 (1985.00x)
#   SpatialLightDistribution
#     Distributions created                                            1158
#     Hash probes per lookup                                          1.014 avg [range 1 - 2]
#     Lookups per distribution                       7254505 /         1158 (6264.68x)
#   Texture
#     Trilinear lookups                                            17838579
#   Profile
#     Integrator::Render()                                            99.74% (   0:00:16.01)
#       Camera::GenerateRay[Differential]()                            8.74% (   0:00:01.40)
#       Film::AddSample()                                              3.10% (   0:00:00.49)
#       Film::MergeTile()                                              0.03% (   0:00:00.00)
#       Sampler::GetSample[12]D()                                      3.41% (   0:00:00.54)
#       Sampler::StartPixelSample()                                    0.02% (   0:00:00.00)
#       SamplerIntegrator::Li()                                       77.98% (   0:00:12.51)
#         Accelerator::Intersect()                                    26.25% (   0:00:04.21)
#           Triangle::Intersect()                                     16.37% (   0:00:02.62)
#         BSDF::Sample_f()                                             2.79% (   0:00:00.44)
#         Direct lighting                                             32.14% (   0:00:05.15)
#           Accelerator::Intersect()                                   5.54% (   0:00:00.88)
#             Triangle::Intersect()                                    1.56% (   0:00:00.25)
#           Accelerator::IntersectP()                                  3.51% (   0:00:00.56)
#             Triangle::IntersectP()                                   0.89% (   0:00:00.14)
#           BSDF::PDF()                                                1.12% (   0:00:00.17)
#           BSDF::Sample_f()                                           2.72% (   0:00:00.43)
#           BSDF::f()                                                  1.66% (   0:00:00.26)
#           Light::Pdf()                                               0.54% (   0:00:00.08)
#           Light::Sample_*()                                          5.50% (   0:00:00.88)
#             MIPMap::Lookup() (trilinear)                             2.39% (   0:00:00.38)
#           MIPMap::Lookup() (trilinear)                               2.06% (   0:00:00.33)
#           Sampler::GetSample[12]D()                                  2.06% (   0:00:00.33)
#         MIPMap::Lookup() (trilinear)                                 1.56% (   0:00:00.25)
#         Material::ComputeScatteringFunctions()                       2.43% (   0:00:00.39)
#         Sampler::GetSample[12]D()                                    0.78% (   0:00:00.12)
#         SpatialLightDistribution lookup                              1.38% (   0:00:00.22)
#           SpatialLightDistribution creation                          0.32% (   0:00:00.05)
#             Light::Sample_*()                                        0.17% (   0:00:00.02)
#               MIPMap::Lookup() (trilinear)                           0.05% (   0:00:00.00)
#     Scene parsing and creation                                       0.26% (   0:00:00.04)
#       Acceleration structure creation                                0.07% (   0:00:00.01)
#   Profile (flattened)
#     Triangle::Intersect()                                           17.94% (   0:00:02.87)
#     Accelerator::Intersect()                                        13.86% (   0:00:02.22)
#     SamplerIntegrator::Li()                                         10.65% (   0:00:01.70)
#     Camera::GenerateRay[Differential]()                              8.74% (   0:00:01.40)
#     Direct lighting                                                  7.43% (   0:00:01.19)
#     Integrator::Render()                                             6.46% (   0:00:01.03)
#     Sampler::GetSample[12]D()                                        6.24% (   0:00:01.00)
#     MIPMap::Lookup() (trilinear)                                     6.06% (   0:00:00.97)
#     BSDF::Sample_f()                                                 5.52% (   0:00:00.88)
#     Light::Sample_*()                                                3.23% (   0:00:00.51)
#     Film::AddSample()                                                3.10% (   0:00:00.49)
#     Accelerator::IntersectP()                                        2.62% (   0:00:00.42)
#     Material::ComputeScatteringFunctions()                           2.43% (   0:00:00.39)
#     BSDF::f()                                                        1.66% (   0:00:00.26)
#     BSDF::PDF()                                                      1.12% (   0:00:00.17)
#     SpatialLightDistribution lookup                                  1.06% (   0:00:00.17)
#     Triangle::IntersectP()                                           0.89% (   0:00:00.14)
#     Light::Pdf()                                                     0.54% (   0:00:00.08)
#     Scene parsing and creation                                       0.20% (   0:00:00.03)
#     SpatialLightDistribution creation                                0.15% (   0:00:00.02)
#     Acceleration structure creation                                  0.07% (   0:00:00.01)
#     Film::MergeTile()                                                0.03% (   0:00:00.00)
#     Sampler::StartPixelSample()                                      0.02% (   0:00:00.00)
#
#
# Finished rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0082.pbrt
#
# Rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0201.pbrt...
# pbrt version 3 (built May  7 2023 at 22:12:21) [Detected 10 cores]
# *** DEBUG BUILD ***
# Copyright (c)1998-2018 Matt Pharr, Greg Humphreys, and Wenzel Jakob.
# The source code to pbrt (but *not* the book contents) is covered by the BSD License.
# See the file LICENSE.txt for the conditions of the license.
# vertices: [ -0.0962986201, 0.977738619, 0.0973889679 ]
# vertices: [ -0.126521513, 1.28458929, 0.127517372 ]
#
# Rendering: [                                           ]
# Rendering: [++                                         ]  (0.3s|4.5s)
# Rendering: [+++++                                      ]  (0.5s|4.1s)
# Rendering: [+++++++                                    ]  (0.8s|3.8s)
# Rendering: [++++++++++                                 ]  (1.0s|3.5s)
# Rendering: [++++++++++++                               ]  (1.3s|3.3s)
# Rendering: [++++++++++++++                             ]  (1.5s|3.0s)
# Rendering: [++++++++++++++++                           ]  (1.8s|2.9s)
# Rendering: [+++++++++++++++++                          ]  (2.0s|3.0s)
# Rendering: [++++++++++++++++++                         ]  (2.3s|3.2s)
# Rendering: [+++++++++++++++++++                        ]  (2.6s|3.4s)
# Rendering: [++++++++++++++++++++                       ]  (3.1s|3.7s)
# Rendering: [+++++++++++++++++++++                      ]  (3.6s|3.9s)
# Rendering: [+++++++++++++++++++++                      ]  (4.1s|4.1s)
# Rendering: [++++++++++++++++++++++                     ]  (4.6s|4.2s)
# Rendering: [+++++++++++++++++++++++                    ]  (5.1s|4.3s)
# Rendering: [++++++++++++++++++++++++                   ]  (5.6s|4.4s)
# Rendering: [+++++++++++++++++++++++++                  ]  (6.1s|4.3s)
# Rendering: [++++++++++++++++++++++++++                 ]  (6.6s|4.3s)
# Rendering: [+++++++++++++++++++++++++++                ]  (7.1s|4.2s)
# Rendering: [++++++++++++++++++++++++++++               ]  (7.6s|4.1s)
# Rendering: [+++++++++++++++++++++++++++++              ]  (8.1s|3.9s)
# Rendering: [++++++++++++++++++++++++++++++             ]  (8.6s|3.7s)
# Rendering: [+++++++++++++++++++++++++++++++            ]  (9.1s|3.5s)
# Rendering: [++++++++++++++++++++++++++++++++           ]  (9.6s|3.2s)
# Rendering: [+++++++++++++++++++++++++++++++++          ]  (10.2s|2.9s)
# Rendering: [++++++++++++++++++++++++++++++++++         ]  (10.7s|2.7s)
# Rendering: [++++++++++++++++++++++++++++++++++++       ]  (11.2s|2.4s)
# Rendering: [+++++++++++++++++++++++++++++++++++++      ]  (11.7s|2.0s)
# Rendering: [++++++++++++++++++++++++++++++++++++++     ]  (12.2s|1.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++    ]  (12.7s|1.4s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++   ]  (13.2s|1.0s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++  ]  (13.7s|0.6s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++ ]  (14.2s|0.3s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (14.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (15.2s)
# Statistics:
#   BVH
#     Interior nodes                                                   3531
#     Leaf nodes                                                       3532
#     Primitives per leaf node                          3970 /         3532 (1.12x)
#   Integrator
#     Camera rays traced                                           12288000
#     Path length                                                     0.584 avg [range 0 - 1]
#     Zero-radiance paths                             540994 /      7259469 (7.45%)
#   Intersections
#     Regular ray intersection tests                               25961879
#     Shadow ray intersection tests                                 3852554
#     Ray-triangle intersection tests                8538211 /     23331115 (36.60%)
#   Memory
#     BVH tree                                                       282.80 kB
#     Film pixels                                                     12.50 MiB
#     Primitives                                                     279.14 kB
#     Texture MIP maps                                                 0.02 kB
#     TransformCache                                                 260.00 kB
#     Triangle meshes                                                361.87 kB
#   Scene
#     Lights                                                              2
#     Materials created                                                   2
#     Shapes created                                                   3970
#     Probes per TransformCache lookup                                1.000 avg [range 1 - 1]
#     TransformCache hits                                  2 /            6 (33.33%)
#     Triangles per triangle mesh                       3970 /            2 (1985.00x)
#   SpatialLightDistribution
#     Distributions created                                            1178
#     Hash probes per lookup                                          1.002 avg [range 1 - 2]
#     Lookups per distribution                       7259469 /         1178 (6162.54x)
#   Texture
#     Trilinear lookups                                            17852921
#   Profile
#     Integrator::Render()                                            99.71% (   0:00:15.49)
#       Camera::GenerateRay[Differential]()                            9.47% (   0:00:01.47)
#       Film::AddSample()                                              3.08% (   0:00:00.47)
#       Film::MergeTile()                                              0.05% (   0:00:00.00)
#       Sampler::GetSample[12]D()                                      3.58% (   0:00:00.55)
#       Sampler::StartPixelSample()                                    0.06% (   0:00:00.00)
#       SamplerIntegrator::Li()                                       76.80% (   0:00:11.93)
#         Accelerator::Intersect()                                    25.71% (   0:00:03.99)
#           Triangle::Intersect()                                     15.74% (   0:00:02.44)
#         BSDF::Sample_f()                                             2.92% (   0:00:00.45)
#         Direct lighting                                             31.84% (   0:00:04.94)
#           Accelerator::Intersect()                                   5.23% (   0:00:00.81)
#             Triangle::Intersect()                                    1.35% (   0:00:00.21)
#           Accelerator::IntersectP()                                  2.96% (   0:00:00.46)
#             Triangle::IntersectP()                                   0.50% (   0:00:00.07)
#           BSDF::PDF()                                                1.01% (   0:00:00.15)
#           BSDF::Sample_f()                                           2.69% (   0:00:00.41)
#           BSDF::f()                                                  1.56% (   0:00:00.24)
#           Light::Pdf()                                               0.49% (   0:00:00.07)
#           Light::Sample_*()                                          5.84% (   0:00:00.90)
#             MIPMap::Lookup() (trilinear)                             2.37% (   0:00:00.36)
#           MIPMap::Lookup() (trilinear)                               2.05% (   0:00:00.31)
#           Sampler::GetSample[12]D()                                  2.12% (   0:00:00.33)
#         MIPMap::Lookup() (trilinear)                                 1.75% (   0:00:00.27)
#         Material::ComputeScatteringFunctions()                       2.37% (   0:00:00.36)
#         Sampler::GetSample[12]D()                                    0.75% (   0:00:00.11)
#         SpatialLightDistribution lookup                              1.20% (   0:00:00.18)
#           SpatialLightDistribution creation                          0.20% (   0:00:00.03)
#             Light::Sample_*()                                        0.09% (   0:00:00.01)
#               MIPMap::Lookup() (trilinear)                           0.03% (   0:00:00.00)
#     Scene parsing and creation                                       0.29% (   0:00:00.04)
#       Acceleration structure creation                                0.07% (   0:00:00.01)
#   Profile (flattened)
#     Triangle::Intersect()                                           17.10% (   0:00:02.65)
#     Accelerator::Intersect()                                        13.84% (   0:00:02.15)
#     SamplerIntegrator::Li()                                         10.26% (   0:00:01.59)
#     Camera::GenerateRay[Differential]()                              9.47% (   0:00:01.47)
#     Direct lighting                                                  7.88% (   0:00:01.22)
#     Integrator::Render()                                             6.68% (   0:00:01.03)
#     Sampler::GetSample[12]D()                                        6.45% (   0:00:01.00)
#     MIPMap::Lookup() (trilinear)                                     6.20% (   0:00:00.96)
#     BSDF::Sample_f()                                                 5.61% (   0:00:00.87)
#     Light::Sample_*()                                                3.53% (   0:00:00.54)
#     Film::AddSample()                                                3.08% (   0:00:00.47)
#     Accelerator::IntersectP()                                        2.46% (   0:00:00.38)
#     Material::ComputeScatteringFunctions()                           2.37% (   0:00:00.36)
#     BSDF::f()                                                        1.56% (   0:00:00.24)
#     BSDF::PDF()                                                      1.01% (   0:00:00.15)
#     SpatialLightDistribution lookup                                  1.00% (   0:00:00.15)
#     Triangle::IntersectP()                                           0.50% (   0:00:00.07)
#     Light::Pdf()                                                     0.49% (   0:00:00.07)
#     Scene parsing and creation                                       0.22% (   0:00:00.03)
#     SpatialLightDistribution creation                                0.11% (   0:00:00.01)
#     Acceleration structure creation                                  0.07% (   0:00:00.01)
#     Sampler::StartPixelSample()                                      0.06% (   0:00:00.00)
#     Film::MergeTile()                                                0.05% (   0:00:00.00)
#
#
# Finished rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0201.pbrt
#
# Rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0190.pbrt...
# pbrt version 3 (built May  7 2023 at 22:12:21) [Detected 10 cores]
# *** DEBUG BUILD ***
# Copyright (c)1998-2018 Matt Pharr, Greg Humphreys, and Wenzel Jakob.
# The source code to pbrt (but *not* the book contents) is covered by the BSD License.
# See the file LICENSE.txt for the conditions of the license.
# vertices: [ -0.0962986201, 0.977738619, 0.0973889679 ]
# vertices: [ -0.126521513, 1.28458929, 0.127517372 ]
#
# Rendering: [                                           ]
# Rendering: [++                                         ]  (0.3s|4.4s)
# Rendering: [+++++                                      ]  (0.5s|4.1s)
# Rendering: [+++++++                                    ]  (0.8s|3.8s)
# Rendering: [++++++++++                                 ]  (1.0s|3.5s)
# Rendering: [++++++++++++                               ]  (1.3s|3.2s)
# Rendering: [++++++++++++++                             ]  (1.5s|3.0s)
# Rendering: [++++++++++++++++                           ]  (1.8s|2.9s)
# Rendering: [+++++++++++++++++                          ]  (2.0s|3.0s)
# Rendering: [++++++++++++++++++                         ]  (2.3s|3.3s)
# Rendering: [+++++++++++++++++++                        ]  (2.6s|3.4s)
# Rendering: [+++++++++++++++++++                        ]  (3.1s|3.7s)
# Rendering: [++++++++++++++++++++                       ]  (3.6s|3.9s)
# Rendering: [+++++++++++++++++++++                      ]  (4.1s|4.1s)
# Rendering: [++++++++++++++++++++++                     ]  (4.6s|4.2s)
# Rendering: [+++++++++++++++++++++++                    ]  (5.1s|4.3s)
# Rendering: [++++++++++++++++++++++++                   ]  (5.6s|4.3s)
# Rendering: [+++++++++++++++++++++++++                  ]  (6.1s|4.3s)
# Rendering: [++++++++++++++++++++++++++                 ]  (6.6s|4.3s)
# Rendering: [+++++++++++++++++++++++++++                ]  (7.1s|4.2s)
# Rendering: [++++++++++++++++++++++++++++               ]  (7.6s|4.1s)
# Rendering: [+++++++++++++++++++++++++++++              ]  (8.1s|3.9s)
# Rendering: [++++++++++++++++++++++++++++++             ]  (8.6s|3.7s)
# Rendering: [+++++++++++++++++++++++++++++++            ]  (9.1s|3.5s)
# Rendering: [++++++++++++++++++++++++++++++++           ]  (9.6s|3.2s)
# Rendering: [+++++++++++++++++++++++++++++++++          ]  (10.1s|3.0s)
# Rendering: [++++++++++++++++++++++++++++++++++         ]  (10.6s|2.6s)
# Rendering: [++++++++++++++++++++++++++++++++++++       ]  (11.1s|2.3s)
# Rendering: [+++++++++++++++++++++++++++++++++++++      ]  (11.7s|2.0s)
# Rendering: [++++++++++++++++++++++++++++++++++++++     ]  (12.2s|1.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++    ]  (12.7s|1.3s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++   ]  (13.2s|1.0s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++  ]  (13.7s|0.6s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++ ]  (14.2s|0.2s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (14.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (15.2s)
# Statistics:
#   BVH
#     Interior nodes                                                   3531
#     Leaf nodes                                                       3532
#     Primitives per leaf node                          3970 /         3532 (1.12x)
#   Integrator
#     Camera rays traced                                           12288000
#     Path length                                                     0.586 avg [range 0 - 1]
#     Zero-radiance paths                             556383 /      7288496 (7.63%)
#   Intersections
#     Regular ray intersection tests                               26070649
#     Shadow ray intersection tests                                 3830985
#     Ray-triangle intersection tests                8569788 /     23040644 (37.19%)
#   Memory
#     BVH tree                                                       282.80 kB
#     Film pixels                                                     12.50 MiB
#     Primitives                                                     279.14 kB
#     Texture MIP maps                                                 0.02 kB
#     TransformCache                                                 260.00 kB
#     Triangle meshes                                                361.87 kB
#   Scene
#     Lights                                                              2
#     Materials created                                                   2
#     Shapes created                                                   3970
#     Probes per TransformCache lookup                                1.000 avg [range 1 - 1]
#     TransformCache hits                                  2 /            6 (33.33%)
#     Triangles per triangle mesh                       3970 /            2 (1985.00x)
#   SpatialLightDistribution
#     Distributions created                                            1216
#     Hash probes per lookup                                          1.004 avg [range 1 - 2]
#     Lookups per distribution                       7288496 /         1216 (5993.83x)
#   Texture
#     Trilinear lookups                                            18006671
#   Profile
#     Integrator::Render()                                            99.69% (   0:00:15.47)
#       Camera::GenerateRay[Differential]()                            9.09% (   0:00:01.41)
#       Film::AddSample()                                              3.07% (   0:00:00.47)
#       Film::MergeTile()                                              0.06% (   0:00:00.00)
#       Sampler::GetSample[12]D()                                      3.57% (   0:00:00.55)
#       Sampler::StartPixelSample()                                    0.05% (   0:00:00.00)
#       SamplerIntegrator::Li()                                       77.60% (   0:00:12.04)
#         Accelerator::Intersect()                                    25.70% (   0:00:03.99)
#           Triangle::Intersect()                                     15.96% (   0:00:02.47)
#         BSDF::Sample_f()                                             2.70% (   0:00:00.41)
#         Direct lighting                                             32.26% (   0:00:05.00)
#           Accelerator::Intersect()                                   5.12% (   0:00:00.79)
#             Triangle::Intersect()                                    1.45% (   0:00:00.22)
#           Accelerator::IntersectP()                                  2.64% (   0:00:00.41)
#             Triangle::IntersectP()                                   0.47% (   0:00:00.07)
#           BSDF::PDF()                                                0.95% (   0:00:00.14)
#           BSDF::Sample_f()                                           2.75% (   0:00:00.42)
#           BSDF::f()                                                  1.73% (   0:00:00.26)
#           Light::Pdf()                                               0.93% (   0:00:00.14)
#           Light::Sample_*()                                          5.41% (   0:00:00.83)
#             MIPMap::Lookup() (trilinear)                             2.32% (   0:00:00.35)
#           MIPMap::Lookup() (trilinear)                               2.23% (   0:00:00.34)
#           Sampler::GetSample[12]D()                                  2.39% (   0:00:00.37)
#         MIPMap::Lookup() (trilinear)                                 1.78% (   0:00:00.27)
#         Material::ComputeScatteringFunctions()                       2.61% (   0:00:00.40)
#         Sampler::GetSample[12]D()                                    0.92% (   0:00:00.14)
#         SpatialLightDistribution lookup                              1.39% (   0:00:00.21)
#           SpatialLightDistribution creation                          0.32% (   0:00:00.04)
#             Light::Sample_*()                                        0.14% (   0:00:00.02)
#               MIPMap::Lookup() (trilinear)                           0.07% (   0:00:00.01)
#     Scene parsing and creation                                       0.31% (   0:00:00.04)
#       Acceleration structure creation                                0.09% (   0:00:00.01)
#   Profile (flattened)
#     Triangle::Intersect()                                           17.41% (   0:00:02.70)
#     Accelerator::Intersect()                                        13.42% (   0:00:02.08)
#     SamplerIntegrator::Li()                                         10.24% (   0:00:01.58)
#     Camera::GenerateRay[Differential]()                              9.09% (   0:00:01.41)
#     Direct lighting                                                  8.10% (   0:00:01.25)
#     Sampler::GetSample[12]D()                                        6.89% (   0:00:01.06)
#     MIPMap::Lookup() (trilinear)                                     6.39% (   0:00:00.99)
#     Integrator::Render()                                             6.25% (   0:00:00.97)
#     BSDF::Sample_f()                                                 5.45% (   0:00:00.84)
#     Light::Sample_*()                                                3.16% (   0:00:00.49)
#     Film::AddSample()                                                3.07% (   0:00:00.47)
#     Material::ComputeScatteringFunctions()                           2.61% (   0:00:00.40)
#     Accelerator::IntersectP()                                        2.17% (   0:00:00.33)
#     BSDF::f()                                                        1.73% (   0:00:00.26)
#     SpatialLightDistribution lookup                                  1.07% (   0:00:00.16)
#     BSDF::PDF()                                                      0.95% (   0:00:00.14)
#     Light::Pdf()                                                     0.93% (   0:00:00.14)
#     Triangle::IntersectP()                                           0.47% (   0:00:00.07)
#     Scene parsing and creation                                       0.22% (   0:00:00.03)
#     SpatialLightDistribution creation                                0.18% (   0:00:00.02)
#     Acceleration structure creation                                  0.09% (   0:00:00.01)
#     Film::MergeTile()                                                0.06% (   0:00:00.00)
#     Sampler::StartPixelSample()                                      0.05% (   0:00:00.00)
#
#
# Finished rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0190.pbrt
#
# Rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0169.pbrt...
# pbrt version 3 (built May  7 2023 at 22:12:21) [Detected 10 cores]
# *** DEBUG BUILD ***
# Copyright (c)1998-2018 Matt Pharr, Greg Humphreys, and Wenzel Jakob.
# The source code to pbrt (but *not* the book contents) is covered by the BSD License.
# See the file LICENSE.txt for the conditions of the license.
# vertices: [ -0.0962986201, 0.977738619, 0.0973889679 ]
# vertices: [ -0.126521513, 1.28458929, 0.127517372 ]
#
# Rendering: [                                           ]
# Rendering: [++                                         ]  (0.3s|4.6s)
# Rendering: [+++++                                      ]  (0.5s|4.2s)
# Rendering: [+++++++                                    ]  (0.8s|3.9s)
# Rendering: [+++++++++                                  ]  (1.0s|3.6s)
# Rendering: [++++++++++++                               ]  (1.3s|3.3s)
# Rendering: [++++++++++++++                             ]  (1.5s|3.1s)
# Rendering: [++++++++++++++++                           ]  (1.8s|3.0s)
# Rendering: [+++++++++++++++++                          ]  (2.0s|3.0s)
# Rendering: [++++++++++++++++++                         ]  (2.3s|3.2s)
# Rendering: [+++++++++++++++++++                        ]  (2.5s|3.4s)
# Rendering: [+++++++++++++++++++                        ]  (3.1s|3.7s)
# Rendering: [++++++++++++++++++++                       ]  (3.6s|3.9s)
# Rendering: [+++++++++++++++++++++                      ]  (4.1s|4.1s)
# Rendering: [++++++++++++++++++++++                     ]  (4.6s|4.2s)
# Rendering: [+++++++++++++++++++++++                    ]  (5.1s|4.3s)
# Rendering: [++++++++++++++++++++++++                   ]  (5.6s|4.4s)
# Rendering: [+++++++++++++++++++++++++                  ]  (6.1s|4.3s)
# Rendering: [++++++++++++++++++++++++++                 ]  (6.6s|4.3s)
# Rendering: [+++++++++++++++++++++++++++                ]  (7.1s|4.2s)
# Rendering: [++++++++++++++++++++++++++++               ]  (7.6s|4.1s)
# Rendering: [+++++++++++++++++++++++++++++              ]  (8.1s|3.9s)
# Rendering: [++++++++++++++++++++++++++++++             ]  (8.6s|3.7s)
# Rendering: [+++++++++++++++++++++++++++++++            ]  (9.1s|3.5s)
# Rendering: [++++++++++++++++++++++++++++++++           ]  (9.6s|3.2s)
# Rendering: [+++++++++++++++++++++++++++++++++          ]  (10.1s|2.9s)
# Rendering: [++++++++++++++++++++++++++++++++++         ]  (10.6s|2.6s)
# Rendering: [++++++++++++++++++++++++++++++++++++       ]  (11.1s|2.4s)
# Rendering: [+++++++++++++++++++++++++++++++++++++      ]  (11.6s|2.0s)
# Rendering: [++++++++++++++++++++++++++++++++++++++     ]  (12.1s|1.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++    ]  (12.6s|1.4s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++   ]  (13.2s|1.0s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++  ]  (13.7s|0.6s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++ ]  (14.2s|0.3s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (14.7s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (15.2s)
# Statistics:
#   BVH
#     Interior nodes                                                   3531
#     Leaf nodes                                                       3532
#     Primitives per leaf node                          3970 /         3532 (1.12x)
#   Integrator
#     Camera rays traced                                           12288000
#     Path length                                                     0.585 avg [range 0 - 1]
#     Zero-radiance paths                             608454 /      7285035 (8.35%)
#   Intersections
#     Regular ray intersection tests                               26137272
#     Shadow ray intersection tests                                 3788526
#     Ray-triangle intersection tests                8606545 /     23303179 (36.93%)
#   Memory
#     BVH tree                                                       282.80 kB
#     Film pixels                                                     12.50 MiB
#     Primitives                                                     279.14 kB
#     Texture MIP maps                                                 0.02 kB
#     TransformCache                                                 260.00 kB
#     Triangle meshes                                                361.87 kB
#   Scene
#     Lights                                                              2
#     Materials created                                                   2
#     Shapes created                                                   3970
#     Probes per TransformCache lookup                                1.000 avg [range 1 - 1]
#     TransformCache hits                                  2 /            6 (33.33%)
#     Triangles per triangle mesh                       3970 /            2 (1985.00x)
#   SpatialLightDistribution
#     Distributions created                                            1216
#     Hash probes per lookup                                          1.011 avg [range 1 - 2]
#     Lookups per distribution                       7285035 /         1216 (5990.98x)
#   Texture
#     Trilinear lookups                                            18167607
#   Profile
#     Integrator::Render()                                            99.71% (   0:00:15.46)
#       Camera::GenerateRay[Differential]()                            9.30% (   0:00:01.44)
#       Film::AddSample()                                              3.44% (   0:00:00.53)
#       Film::MergeTile()                                              0.09% (   0:00:00.01)
#       Sampler::GetSample[12]D()                                      3.53% (   0:00:00.54)
#       Sampler::StartPixelSample()                                    0.04% (   0:00:00.00)
#       SamplerIntegrator::Li()                                       76.79% (   0:00:11.90)
#         Accelerator::Intersect()                                    24.34% (   0:00:03.77)
#           Triangle::Intersect()                                     15.03% (   0:00:02.33)
#         BSDF::Sample_f()                                             2.82% (   0:00:00.43)
#         Direct lighting                                             32.65% (   0:00:05.06)
#           Accelerator::Intersect()                                   5.61% (   0:00:00.86)
#             Triangle::Intersect()                                    1.66% (   0:00:00.25)
#           Accelerator::IntersectP()                                  2.96% (   0:00:00.45)
#             Triangle::IntersectP()                                   0.52% (   0:00:00.08)
#           BSDF::PDF()                                                1.10% (   0:00:00.17)
# ...
#     TransformCache hits                                  2 /            6 (33.33%)
#     Triangles per triangle mesh                       3970 /            2 (1985.00x)
#   SpatialLightDistribution
#     Distributions created                                            1177
#     Hash probes per lookup                                          1.001 avg [range 1 - 2]
#     Lookups per distribution                       7268722 /         1177 (6175.63x)
#   Texture
#     Trilinear lookups                                            17404256
#   Profile
#     Integrator::Render()                                            99.72% (   0:00:14.94)
#       Camera::GenerateRay[Differential]()                            9.59% (   0:00:01.43)
#       Film::AddSample()                                              3.23% (   0:00:00.48)
#       Film::MergeTile()                                              0.04% (   0:00:00.00)
#       Sampler::GetSample[12]D()                                      3.52% (   0:00:00.52)
#       Sampler::StartPixelSample()                                    0.04% (   0:00:00.00)
#       SamplerIntegrator::Li()                                       76.96% (   0:00:11.53)
#         Accelerator::Intersect()                                    25.93% (   0:00:03.88)
#           Triangle::Intersect()                                     15.65% (   0:00:02.34)
#         BSDF::Sample_f()                                             2.94% (   0:00:00.44)
#         Direct lighting                                             31.34% (   0:00:04.69)
#           Accelerator::Intersect()                                   5.20% (   0:00:00.77)
#             Triangle::Intersect()                                    1.56% (   0:00:00.23)
#           Accelerator::IntersectP()                                  3.10% (   0:00:00.46)
#             Triangle::IntersectP()                                   0.75% (   0:00:00.11)
#           BSDF::PDF()                                                1.19% (   0:00:00.17)
#           BSDF::Sample_f()                                           2.51% (   0:00:00.37)
#           BSDF::f()                                                  1.59% (   0:00:00.23)
#           Light::Pdf()                                               0.76% (   0:00:00.11)
#           Light::Sample_*()                                          5.65% (   0:00:00.84)
#             MIPMap::Lookup() (trilinear)                             2.24% (   0:00:00.33)
#           MIPMap::Lookup() (trilinear)                               1.78% (   0:00:00.26)
#           Sampler::GetSample[12]D()                                  2.20% (   0:00:00.32)
#         MIPMap::Lookup() (trilinear)                                 1.53% (   0:00:00.22)
#         Material::ComputeScatteringFunctions()                       2.70% (   0:00:00.40)
#         Sampler::GetSample[12]D()                                    0.72% (   0:00:00.10)
#         SpatialLightDistribution lookup                              1.37% (   0:00:00.20)
#           SpatialLightDistribution creation                          0.38% (   0:00:00.05)
#             Light::Sample_*()                                        0.24% (   0:00:00.03)
#               MIPMap::Lookup() (trilinear)                           0.06% (   0:00:00.00)
#     Scene parsing and creation                                       0.28% (   0:00:00.04)
#       Acceleration structure creation                                0.07% (   0:00:00.01)
#   Profile (flattened)
#     Triangle::Intersect()                                           17.21% (   0:00:02.58)
#     Accelerator::Intersect()                                        13.91% (   0:00:02.08)
#     SamplerIntegrator::Li()                                         10.45% (   0:00:01.56)
#     Camera::GenerateRay[Differential]()                              9.59% (   0:00:01.43)
#     Direct lighting                                                  7.37% (   0:00:01.10)
#     Sampler::GetSample[12]D()                                        6.44% (   0:00:00.96)
#     Integrator::Render()                                             6.34% (   0:00:00.95)
#     MIPMap::Lookup() (trilinear)                                     5.60% (   0:00:00.83)
#     BSDF::Sample_f()                                                 5.45% (   0:00:00.81)
#     Light::Sample_*()                                                3.60% (   0:00:00.54)
#     Film::AddSample()                                                3.23% (   0:00:00.48)
#     Material::ComputeScatteringFunctions()                           2.70% (   0:00:00.40)
#     Accelerator::IntersectP()                                        2.35% (   0:00:00.35)
#     BSDF::f()                                                        1.59% (   0:00:00.23)
#     BSDF::PDF()                                                      1.19% (   0:00:00.17)
#     SpatialLightDistribution lookup                                  0.98% (   0:00:00.14)
#     Light::Pdf()                                                     0.76% (   0:00:00.11)
#     Triangle::IntersectP()                                           0.75% (   0:00:00.11)
#     Scene parsing and creation                                       0.21% (   0:00:00.03)
#     SpatialLightDistribution creation                                0.14% (   0:00:00.02)
#     Acceleration structure creation                                  0.07% (   0:00:00.01)
#     Sampler::StartPixelSample()                                      0.04% (   0:00:00.00)
#     Film::MergeTile()                                                0.04% (   0:00:00.00)
#
#
# Finished rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0042.pbrt
#
# Rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0150.pbrt...
# pbrt version 3 (built May  7 2023 at 22:12:21) [Detected 10 cores]
# *** DEBUG BUILD ***
# Copyright (c)1998-2018 Matt Pharr, Greg Humphreys, and Wenzel Jakob.
# The source code to pbrt (but *not* the book contents) is covered by the BSD License.
# See the file LICENSE.txt for the conditions of the license.
# vertices: [ -0.0962986201, 0.977738619, 0.0973889679 ]
# vertices: [ -0.126521513, 1.28458929, 0.127517372 ]
#
# Rendering: [                                           ]
# Rendering: [++                                         ]  (0.3s|4.4s)
# Rendering: [+++++                                      ]  (0.5s|4.1s)
# Rendering: [+++++++                                    ]  (0.8s|3.8s)
# Rendering: [++++++++++                                 ]  (1.0s|3.5s)
# Rendering: [++++++++++++                               ]  (1.3s|3.2s)
# Rendering: [+++++++++++++++                            ]  (1.5s|3.0s)
# Rendering: [+++++++++++++++++                          ]  (1.8s|2.9s)
# Rendering: [++++++++++++++++++                         ]  (2.0s|3.0s)
# Rendering: [++++++++++++++++++                         ]  (2.3s|3.1s)
# Rendering: [+++++++++++++++++++                        ]  (2.6s|3.3s)
# Rendering: [++++++++++++++++++++                       ]  (3.1s|3.6s)
# Rendering: [+++++++++++++++++++++                      ]  (3.6s|3.9s)
# Rendering: [++++++++++++++++++++++                     ]  (4.1s|4.0s)
# Rendering: [+++++++++++++++++++++++                    ]  (4.6s|4.1s)
# Rendering: [++++++++++++++++++++++++                   ]  (5.1s|4.2s)
# Rendering: [++++++++++++++++++++++++                   ]  (5.6s|4.2s)
# Rendering: [+++++++++++++++++++++++++                  ]  (6.1s|4.3s)
# Rendering: [++++++++++++++++++++++++++                 ]  (6.6s|4.2s)
# Rendering: [+++++++++++++++++++++++++++                ]  (7.1s|4.1s)
# Rendering: [++++++++++++++++++++++++++++               ]  (7.6s|4.0s)
# Rendering: [+++++++++++++++++++++++++++++              ]  (8.1s|3.8s)
# Rendering: [++++++++++++++++++++++++++++++             ]  (8.6s|3.6s)
# Rendering: [++++++++++++++++++++++++++++++++           ]  (9.1s|3.3s)
# Rendering: [+++++++++++++++++++++++++++++++++          ]  (9.6s|3.1s)
# Rendering: [++++++++++++++++++++++++++++++++++         ]  (10.1s|2.8s)
# Rendering: [+++++++++++++++++++++++++++++++++++        ]  (10.6s|2.5s)
# Rendering: [++++++++++++++++++++++++++++++++++++       ]  (11.2s|2.2s)
# Rendering: [+++++++++++++++++++++++++++++++++++++      ]  (11.7s|1.9s)
# Rendering: [++++++++++++++++++++++++++++++++++++++     ]  (12.2s|1.5s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++    ]  (12.7s|1.2s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++   ]  (13.2s|0.8s)
# Rendering: [++++++++++++++++++++++++++++++++++++++++++ ]  (13.7s|0.5s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (14.2s|0.1s)
# Rendering: [+++++++++++++++++++++++++++++++++++++++++++]  (14.7s)
# Statistics:
#   BVH
#     Interior nodes                                                   3531
#     Leaf nodes                                                       3532
#     Primitives per leaf node                          3970 /         3532 (1.12x)
#   Integrator
#     Camera rays traced                                           12288000
#     Path length                                                     0.580 avg [range 0 - 1]
#     Zero-radiance paths                             682988 /      7236033 (9.44%)
#   Intersections
#     Regular ray intersection tests                               26064648
#     Shadow ray intersection tests                                 3746610
#     Ray-triangle intersection tests                8628917 /     23955725 (36.02%)
#   Memory
#     BVH tree                                                       282.80 kB
#     Film pixels                                                     12.50 MiB
#     Primitives                                                     279.14 kB
#     Texture MIP maps                                                 0.02 kB
#     TransformCache                                                 260.00 kB
#     Triangle meshes                                                361.87 kB
#   Scene
#     Lights                                                              2
#     Materials created                                                   2
#     Shapes created                                                   3970
#     Probes per TransformCache lookup                                1.000 avg [range 1 - 1]
#     TransformCache hits                                  2 /            6 (33.33%)
#     Triangles per triangle mesh                       3970 /            2 (1985.00x)
#   SpatialLightDistribution
#     Distributions created                                            1129
#     Hash probes per lookup                                          1.009 avg [range 1 - 2]
#     Lookups per distribution                       7236033 /         1129 (6409.24x)
#   Texture
#     Trilinear lookups                                            18186616
#   Profile
#     Integrator::Render()                                            99.72% (   0:00:14.94)
#       Camera::GenerateRay[Differential]()                            9.14% (   0:00:01.37)
#       Film::AddSample()                                              3.22% (   0:00:00.48)
#       Film::MergeTile()                                              0.07% (   0:00:00.00)
#       Sampler::GetSample[12]D()                                      3.49% (   0:00:00.52)
#       Sampler::StartPixelSample()                                    0.04% (   0:00:00.00)
#       SamplerIntegrator::Li()                                       77.29% (   0:00:11.58)
#         Accelerator::Intersect()                                    24.43% (   0:00:03.66)
#           Triangle::Intersect()                                     15.15% (   0:00:02.27)
#         BSDF::Sample_f()                                             3.03% (   0:00:00.45)
#         Direct lighting                                             33.22% (   0:00:04.97)
#           Accelerator::Intersect()                                   5.43% (   0:00:00.81)
#             Triangle::Intersect()                                    1.22% (   0:00:00.18)
#           Accelerator::IntersectP()                                  3.26% (   0:00:00.48)
#             Triangle::IntersectP()                                   0.69% (   0:00:00.10)
#           BSDF::PDF()                                                1.05% (   0:00:00.15)
#           BSDF::Sample_f()                                           3.04% (   0:00:00.45)
#           BSDF::f()                                                  1.55% (   0:00:00.23)
#           Light::Pdf()                                               0.75% (   0:00:00.11)
#           Light::Sample_*()                                          5.79% (   0:00:00.86)
#             MIPMap::Lookup() (trilinear)                             2.32% (   0:00:00.34)
#           MIPMap::Lookup() (trilinear)                               2.07% (   0:00:00.31)
#           Sampler::GetSample[12]D()                                  2.15% (   0:00:00.32)
#         MIPMap::Lookup() (trilinear)                                 1.83% (   0:00:00.27)
#         Material::ComputeScatteringFunctions()                       2.45% (   0:00:00.36)
#         Sampler::GetSample[12]D()                                    0.79% (   0:00:00.11)
#         SpatialLightDistribution lookup                              1.33% (   0:00:00.19)
#           SpatialLightDistribution creation                          0.35% (   0:00:00.05)
#             Light::Sample_*()                                        0.16% (   0:00:00.02)
#               MIPMap::Lookup() (trilinear)                           0.04% (   0:00:00.00)
#     Scene parsing and creation                                       0.28% (   0:00:00.04)
#       Acceleration structure creation                                0.08% (   0:00:00.01)
#   Profile (flattened)
#     Triangle::Intersect()                                           16.37% (   0:00:02.45)
#     Accelerator::Intersect()                                        13.48% (   0:00:02.02)
#     SamplerIntegrator::Li()                                         10.20% (   0:00:01.52)
#     Camera::GenerateRay[Differential]()                              9.14% (   0:00:01.37)
#     Direct lighting                                                  8.14% (   0:00:01.22)
#     Integrator::Render()                                             6.47% (   0:00:00.96)
#     Sampler::GetSample[12]D()                                        6.43% (   0:00:00.96)
#     MIPMap::Lookup() (trilinear)                                     6.26% (   0:00:00.93)
#     BSDF::Sample_f()                                                 6.06% (   0:00:00.90)
#     Light::Sample_*()                                                3.59% (   0:00:00.53)
#     Film::AddSample()                                                3.22% (   0:00:00.48)
#     Accelerator::IntersectP()                                        2.57% (   0:00:00.38)
#     Material::ComputeScatteringFunctions()                           2.45% (   0:00:00.36)
#     BSDF::f()                                                        1.55% (   0:00:00.23)
#     BSDF::PDF()                                                      1.05% (   0:00:00.15)
#     SpatialLightDistribution lookup                                  0.98% (   0:00:00.14)
#     Light::Pdf()                                                     0.75% (   0:00:00.11)
#     Triangle::IntersectP()                                           0.69% (   0:00:00.10)
#     Scene parsing and creation                                       0.21% (   0:00:00.03)
#     SpatialLightDistribution creation                                0.19% (   0:00:00.02)
#     Acceleration structure creation                                  0.08% (   0:00:00.01)
#     Film::MergeTile()                                                0.07% (   0:00:00.00)
#     Sampler::StartPixelSample()                                      0.04% (   0:00:00.00)
#
#
# Finished rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0150.pbrt
#
# Rendering /Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/rotated_0015.pbrt...

# %%
import os

def generate_pbrt_file(input_file, output_dir, rotation_angle, num_files):
    with open(input_file, 'r') as file:
        content = file.readlines()

    for i in range(num_files):
        angle_rad = math.radians(i * rotation_angle)
        x = -10 * math.sin(angle_rad)
        z = -10 * math.cos(angle_rad)

        new_content = []
        for line in content:
            if line.startswith("LookAt"):
                new_content.append(f"LookAt {x} {z} 2 # eye\n")
            elif "matte_dsphere" in line:
                # 使用字符串格式化操作符将计数器值格式化为指定位数的字符串
                new_filename = "{:04d}.png".format(i + 1)
                new_content.append(f'Film "image" "string filename" "{new_filename}" ')
            else:
                new_content.append(line)

        output_file = os.path.join(output_dir, f"rotated_{i+1:04d}.pbrt")
        with open(output_file, 'w') as file:
            file.writelines(new_content)

input_file = "/Users/mitty/Documents/GitHub/pbrt-v3-coursework/test/test.pbrt"
output_dir = "/Users/mitty/Documents/GitHub/pbrt-v3-coursework/test"

num_files = 240
rotation_angle = 360 / num_files

generate_pbrt_file(input_file, output_dir, rotation_angle, num_files)
